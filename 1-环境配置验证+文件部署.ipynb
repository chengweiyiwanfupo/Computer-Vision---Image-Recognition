# %%
#验证环境配置是否成功

# %%
import torch, torchvision
print('Pytorch 版本', torch.__version__)
print('CUDA 是否可用',torch.cuda.is_available())

import mmcv
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print('MMCV版本', mmcv.__version__)
print('CUDA版本', get_compiling_cuda_version())
print('编译器版本', get_compiler_version())

import mmseg
from mmseg.utils import register_all_modules
from mmseg.apis import inference_model, init_model
print('mmsegmentation版本', mmseg.__version__)
# Out:
# Pytorch 版本 2.0.0
# CUDA 是否可用 True
# MMCV版本 2.0.0
# CUDA版本 11.8
# 编译器版本 MSVC 192829924
# mmsegmentation版本 1.2.2

# %%
import matplotlib 

matplotlib.rc("font",family='SimHei') # 中文字体

import matplotlib.pyplot as plt

plt.plot([1,2,3], [100,500,300])
plt.title('matplotlib中文字体测试', fontsize=8)
plt.xlabel('X轴', fontsize=8)
plt.ylabel('Y轴', fontsize=8)
plt.show()

# %%
#
import os
os.chdir("D:\\jupyter notebook\\SegFormer")

import os

# 创建 data 文件夹，用于存放图片和视频素材,我提供了几张图片，你可以将图片放置进去
os.mkdir('data')

# 创建 checkpoint 文件夹，用于存放预训练模型权重文件
os.mkdir('checkpoint')

# 创建 outputs 文件夹，用于存放预测结果
os.mkdir('outputs')

# %%
#查看一下有哪些配置文件，这里以segformer模型为示例
from PIL import Image
import os
print(os.listdir('configs/segformer'))

# %%
#查看 Python 解释器的路径，确保当前正在使用的 Python 解释器的绝对路径，与后续图像识别的路径一致
import sys
print(sys.executable)
# !where python
